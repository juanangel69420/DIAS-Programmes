# %%
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
small_step = np.loadtxt("C:\\Users\\cilli\\VS programmes\\smallstep.txt", dtype = "double", delimiter = ",")
big_step = np.loadtxt("C:\\Users\\cilli\\VS programmes\\bigstep.txt", dtype = "double", delimiter = ",")

# %%
# The coordinates of a system evolved to t = 1000 starting from some thermalised state.
# small step evolves the system with a step size of 10^-4 and big step evolves the system using a step size
# of 1x10^-3

x1_small = small_step[:100]
x2_small = small_step[100:200]
y1_small = small_step[200:300]
y2_small = small_step[300:400]
px1_small = small_step[400:500]
px2_small = small_step[500:600]
py1_small = small_step[600:700]
py2_small = small_step[700:]

x1_big = big_step[:100]
x2_big = big_step[100:200]
y1_big = big_step[200:300]
y2_big = big_step[300:400]
px1_big = big_step[400:500]
px2_big = big_step[500:600]
py1_big = big_step[600:700]
py2_big = big_step[700:]

# %%
plt.figure(figsize = (15,15))
times = np.linspace(0,1000,100)

plt.subplot(4,2,1)
plt.scatter(times, x1_small - x1_big)
plt.xlabel("time")
plt.ylabel("x1_small - x1_big")

plt.subplot(4,2,2)
plt.scatter(times, x2_small - x2_big)
plt.xlabel("time")
plt.ylabel("x2_small - x2_big")

plt.subplot(4,2,3)
plt.scatter(times, y1_small - y1_big)
plt.xlabel("time")
plt.ylabel("y1_small - y2_big")

plt.subplot(4,2,4)
plt.scatter(times, y2_small - y2_big)
plt.xlabel("time")
plt.ylabel("y2_small - y2_big")

plt.subplot(4,2,5)
plt.scatter(times, px1_small - px1_big)
plt.xlabel("time")
plt.ylabel("px1_small - px1_big")

plt.subplot(4,2,6)
plt.scatter(times, px2_small - px2_big)
plt.xlabel("time")
plt.ylabel("px2_small - px2_big")

plt.subplot(4,2,7)
plt.scatter(times, py1_small - py1_big)
plt.xlabel("time")
plt.ylabel("py1_small - py1_big")

plt.subplot(4,2,8)
plt.scatter(times, py2_small - py2_big)
plt.xlabel("time")
plt.ylabel("py2_small - py2_big");

plt.savefig("asd")

# %%
# Importing solution arrays for simulation 1

simulate_1 = np.loadtxt("C:\\Users\\cilli\\VS programmes\\run_1.txt", dtype = "double", delimiter = ",")
simulate_ds1= np.loadtxt("C:\\Users\\cilli\\VS programmes\\run_ds1.txt", dtype = "double", delimiter = ",")
simulate_2 = np.loadtxt("C:\\Users\\cilli\\VS programmes\\run_2.txt", dtype = "double", delimiter = ",")
simulate_ds2 = np.loadtxt("C:\\Users\\cilli\\VS programmes\\run_ds2.txt", dtype = "double", delimiter = ",")
simulate_3 = np.loadtxt("C:\\Users\\cilli\\VS programmes\\run_3.txt", dtype = "double", delimiter = ",")
simulate_ds3 = np.loadtxt("C:\\Users\\cilli\\VS programmes\\run_ds3.txt", dtype = "double", delimiter = ",")
simulate_4 = np.loadtxt("C:\\Users\\cilli\\VS programmes\\run_4.txt", dtype = "double", delimiter = ",")
simulate_ds4 =np.loadtxt("C:\\Users\\cilli\\VS programmes\\run_ds4.txt", dtype = "double", delimiter = ",")
simulate_5 =np.loadtxt("C:\\Users\\cilli\\VS programmes\\run_5.txt", dtype = "double", delimiter = ",")
simulate_ds5 =np.loadtxt("C:\\Users\\cilli\\VS programmes\\run_ds5.txt", dtype = "double", delimiter = ",")
simulate_6 =np.loadtxt("C:\\Users\\cilli\\VS programmes\\run_6.txt", dtype = "double", delimiter = ",")
simulate_ds6 =np.loadtxt("C:\\Users\\cilli\\VS programmes\\run_ds6.txt", dtype = "double", delimiter = ",")
simulate_7 =np.loadtxt("C:\\Users\\cilli\\VS programmes\\run_7.txt", dtype = "double", delimiter = ",")
simulate_ds7 =np.loadtxt("C:\\Users\\cilli\\VS programmes\\run_ds7.txt", dtype = "double", delimiter = ",")
simulate_8 =np.loadtxt("C:\\Users\\cilli\\VS programmes\\run_8.txt", dtype = "double", delimiter = ",")
simulate_ds8 =np.loadtxt("C:\\Users\\cilli\\VS programmes\\run_ds8.txt", dtype = "double", delimiter = ",")
simulate_9 =np.loadtxt("C:\\Users\\cilli\\VS programmes\\run_9.txt", dtype = "double", delimiter = ",")
simulate_ds9 =np.loadtxt("C:\\Users\\cilli\\VS programmes\\run_ds9.txt", dtype = "double", delimiter = ",")
simulate_10 =np.loadtxt("C:\\Users\\cilli\\VS programmes\\run_10.txt", dtype = "double", delimiter = ",")
simulate_ds10 = np.loadtxt("C:\\Users\\cilli\\VS programmes\\run_ds10.txt", dtype = "double", delimiter = ",")

simulate_11 = np.loadtxt("C:\\Users\\cilli\\VS programmes\\run_11.txt", dtype = "double", delimiter = ",")
simulate_ds11 =np.loadtxt("C:\\Users\\cilli\\VS programmes\\run_ds11.txt", dtype = "double", delimiter = ",")
simulate_12 = np.loadtxt("C:\\Users\\cilli\\VS programmes\\run_12.txt", dtype = "double", delimiter = ",")
simulate_ds12 = np.loadtxt("C:\\Users\\cilli\\VS programmes\\run_ds12.txt", dtype = "double", delimiter = ",")
simulate_13 = np.loadtxt("C:\\Users\\cilli\\VS programmes\\run_13.txt", dtype = "double", delimiter = ",")
simulate_ds13 = np.loadtxt("C:\\Users\\cilli\\VS programmes\\run_ds13.txt", dtype = "double", delimiter = ",")
simulate_14 = np.loadtxt("C:\\Users\\cilli\\VS programmes\\run_14.txt", dtype = "double", delimiter = ",")
simulate_ds14 = np.loadtxt("C:\\Users\\cilli\\VS programmes\\run_ds14.txt", dtype = "double", delimiter = ",")
simulate_15 = np.loadtxt("C:\\Users\\cilli\\VS programmes\\run_15.txt", dtype = "double", delimiter = ",")
simulate_ds15 = np.loadtxt("C:\\Users\\cilli\\VS programmes\\run_ds15.txt", dtype = "double", delimiter = ",")
simulate_16 = np.loadtxt("C:\\Users\\cilli\\VS programmes\\run_16.txt", dtype = "double", delimiter = ",")
simulate_ds16 = np.loadtxt("C:\\Users\\cilli\\VS programmes\\run_ds16.txt", dtype = "double", delimiter = ",")
simulate_17 = np.loadtxt("C:\\Users\\cilli\\VS programmes\\run_17.txt", dtype = "double", delimiter = ",")
simulate_ds17 =np.loadtxt("C:\\Users\\cilli\\VS programmes\\run_ds17.txt", dtype = "double", delimiter = ",")
simulate_18 = np.loadtxt("C:\\Users\\cilli\\VS programmes\\run_18.txt", dtype = "double", delimiter = ",")
simulate_ds18 = np.loadtxt("C:\\Users\\cilli\\VS programmes\\run_ds18.txt", dtype = "double", delimiter = ",")
simulate_19 = np.loadtxt("C:\\Users\\cilli\\VS programmes\\run_19.txt", dtype = "double", delimiter = ",")
simulate_ds19 = np.loadtxt("C:\\Users\\cilli\\VS programmes\\run_ds19.txt", dtype = "double", delimiter = ",")
simulate_20 = np.loadtxt("C:\\Users\\cilli\\VS programmes\\run_20.txt", dtype = "double", delimiter = ",")
simulate_ds20 = np.loadtxt("C:\\Users\\cilli\\VS programmes\\run_ds20.txt", dtype = "double", delimiter = ",")

# %%
# indexer is used to seperate my text file into seperate coordinates
indexer = int(len(simulate_1) / 8)

##1
sols_1 = np.array([
    simulate_1[:indexer],simulate_1[indexer:2*indexer],simulate_1[2*indexer:3*indexer],simulate_1[3*indexer:4*indexer],
    simulate_1[4*indexer:5*indexer],simulate_1[5*indexer:6*indexer],simulate_1[6*indexer:7*indexer],simulate_1[7*indexer:]
])
sols_ds1 = np.array([
    simulate_ds1[:indexer],simulate_ds1[indexer:2*indexer],simulate_ds1[2*indexer:3*indexer],simulate_ds1[3*indexer:4*indexer],
    simulate_ds1[4*indexer:5*indexer],simulate_ds1[5*indexer:6*indexer],simulate_ds1[6*indexer:7*indexer],simulate_ds1[7*indexer:]
])
##2
sols_2 = np.array([
    simulate_2[:indexer],simulate_2[indexer:2*indexer],simulate_2[2*indexer:3*indexer],simulate_2[3*indexer:4*indexer],
    simulate_2[4*indexer:5*indexer],simulate_2[5*indexer:6*indexer],simulate_2[6*indexer:7*indexer],simulate_2[7*indexer:]
])
sols_ds2 = np.array([
    simulate_ds2[:indexer],simulate_ds2[indexer:2*indexer],simulate_ds2[2*indexer:3*indexer],simulate_ds2[3*indexer:4*indexer],
    simulate_ds2[4*indexer:5*indexer],simulate_ds2[5*indexer:6*indexer],simulate_ds2[6*indexer:7*indexer],simulate_ds2[7*indexer:]
])
##3
sols_3 = np.array([
    simulate_3[:indexer],simulate_3[indexer:2*indexer],simulate_3[2*indexer:3*indexer],simulate_3[3*indexer:4*indexer],
    simulate_3[4*indexer:5*indexer],simulate_3[5*indexer:6*indexer],simulate_3[6*indexer:7*indexer],simulate_3[7*indexer:]
])
sols_ds3 = np.array([
    simulate_ds3[:indexer],simulate_ds3[indexer:2*indexer],simulate_ds3[2*indexer:3*indexer],simulate_ds3[3*indexer:4*indexer],
    simulate_ds3[4*indexer:5*indexer],simulate_ds3[5*indexer:6*indexer],simulate_ds3[6*indexer:7*indexer],simulate_ds3[7*indexer:]
])
##4
sols_4 = np.array([
    simulate_4[:indexer],simulate_4[indexer:2*indexer],simulate_4[2*indexer:3*indexer],simulate_4[3*indexer:4*indexer],
    simulate_4[4*indexer:5*indexer],simulate_4[5*indexer:6*indexer],simulate_4[6*indexer:7*indexer],simulate_4[7*indexer:]
])
sols_ds4 = np.array([
    simulate_ds4[:indexer],simulate_ds4[indexer:2*indexer],simulate_ds4[2*indexer:3*indexer],simulate_ds4[3*indexer:4*indexer],
    simulate_ds4[4*indexer:5*indexer],simulate_ds4[5*indexer:6*indexer],simulate_ds4[6*indexer:7*indexer],simulate_ds4[7*indexer:]
])
##5
sols_5 = np.array([
    simulate_5[:indexer],simulate_5[indexer:2*indexer],simulate_5[2*indexer:3*indexer],simulate_5[3*indexer:4*indexer],
    simulate_5[4*indexer:5*indexer],simulate_5[5*indexer:6*indexer],simulate_5[6*indexer:7*indexer],simulate_5[7*indexer:]
])
sols_ds5 = np.array([
    simulate_ds5[:indexer],simulate_ds5[indexer:2*indexer],simulate_ds5[2*indexer:3*indexer],simulate_ds5[3*indexer:4*indexer],
    simulate_ds5[4*indexer:5*indexer],simulate_ds5[5*indexer:6*indexer],simulate_ds5[6*indexer:7*indexer],simulate_ds5[7*indexer:]
])
##6
sols_6 = np.array([
    simulate_6[:indexer],simulate_6[indexer:2*indexer],simulate_6[2*indexer:3*indexer],simulate_6[3*indexer:4*indexer],
    simulate_6[4*indexer:5*indexer],simulate_6[5*indexer:6*indexer],simulate_6[6*indexer:7*indexer],simulate_6[7*indexer:]
])
sols_ds6 = np.array([
    simulate_ds6[:indexer],simulate_ds6[indexer:2*indexer],simulate_ds6[2*indexer:3*indexer],simulate_ds6[3*indexer:4*indexer],
    simulate_ds6[4*indexer:5*indexer],simulate_ds6[5*indexer:6*indexer],simulate_ds6[6*indexer:7*indexer],simulate_ds6[7*indexer:]
])
##7
sols_7 = np.array([
    simulate_7[:indexer],simulate_7[indexer:2*indexer],simulate_7[2*indexer:3*indexer],simulate_7[3*indexer:4*indexer],
    simulate_7[4*indexer:5*indexer],simulate_7[5*indexer:6*indexer],simulate_7[6*indexer:7*indexer],simulate_7[7*indexer:]
])
sols_ds7 = np.array([
    simulate_ds7[:indexer],simulate_ds7[indexer:2*indexer],simulate_ds7[2*indexer:3*indexer],simulate_ds7[3*indexer:4*indexer],
    simulate_ds7[4*indexer:5*indexer],simulate_ds7[5*indexer:6*indexer],simulate_ds7[6*indexer:7*indexer],simulate_ds7[7*indexer:]
])
##8
sols_8 = np.array([
    simulate_8[:indexer],simulate_8[indexer:2*indexer],simulate_8[2*indexer:3*indexer],simulate_8[3*indexer:4*indexer],
    simulate_8[4*indexer:5*indexer],simulate_8[5*indexer:6*indexer],simulate_8[6*indexer:7*indexer],simulate_8[7*indexer:]
])
sols_ds8 = np.array([
    simulate_ds8[:indexer],simulate_ds8[indexer:2*indexer],simulate_ds8[2*indexer:3*indexer],simulate_ds8[3*indexer:4*indexer],
    simulate_ds8[4*indexer:5*indexer],simulate_ds8[5*indexer:6*indexer],simulate_ds8[6*indexer:7*indexer],simulate_ds8[7*indexer:]
])
##9
sols_9 = np.array([
    simulate_9[:indexer],simulate_9[indexer:2*indexer],simulate_9[2*indexer:3*indexer],simulate_9[3*indexer:4*indexer],
    simulate_9[4*indexer:5*indexer],simulate_9[5*indexer:6*indexer],simulate_9[6*indexer:7*indexer],simulate_9[7*indexer:]
])
sols_ds9 = np.array([
    simulate_ds9[:indexer],simulate_ds9[indexer:2*indexer],simulate_ds9[2*indexer:3*indexer],simulate_ds9[3*indexer:4*indexer],
    simulate_ds9[4*indexer:5*indexer],simulate_ds9[5*indexer:6*indexer],simulate_ds9[6*indexer:7*indexer],simulate_ds9[7*indexer:]
])
##10
sols_10 = np.array([
    simulate_10[:indexer],simulate_10[indexer:2*indexer],simulate_10[2*indexer:3*indexer],simulate_10[3*indexer:4*indexer],
    simulate_10[4*indexer:5*indexer],simulate_10[5*indexer:6*indexer],simulate_10[6*indexer:7*indexer],simulate_10[7*indexer:]
])
sols_ds10 = np.array([
    simulate_ds10[:indexer],simulate_ds10[indexer:2*indexer],simulate_ds10[2*indexer:3*indexer],simulate_ds10[3*indexer:4*indexer],
    simulate_ds10[4*indexer:5*indexer],simulate_ds10[5*indexer:6*indexer],simulate_ds10[6*indexer:7*indexer],simulate_ds10[7*indexer:]
])
##11
sols_11 = np.array([
    simulate_11[:indexer],simulate_11[indexer:2*indexer],simulate_11[2*indexer:3*indexer],simulate_11[3*indexer:4*indexer],
    simulate_11[4*indexer:5*indexer],simulate_11[5*indexer:6*indexer],simulate_11[6*indexer:7*indexer],simulate_11[7*indexer:]
])
sols_ds11 = np.array([
    simulate_ds11[:indexer],simulate_ds11[indexer:2*indexer],simulate_ds11[2*indexer:3*indexer],simulate_ds11[3*indexer:4*indexer],
    simulate_ds11[4*indexer:5*indexer],simulate_ds11[5*indexer:6*indexer],simulate_ds11[6*indexer:7*indexer],simulate_ds11[7*indexer:]
])
##12
sols_12 = np.array([
    simulate_12[:indexer],simulate_12[indexer:2*indexer],simulate_12[2*indexer:3*indexer],simulate_12[3*indexer:4*indexer],
    simulate_12[4*indexer:5*indexer],simulate_12[5*indexer:6*indexer],simulate_12[6*indexer:7*indexer],simulate_12[7*indexer:]
])
sols_ds12 = np.array([
    simulate_ds12[:indexer],simulate_ds12[indexer:2*indexer],simulate_ds12[2*indexer:3*indexer],simulate_ds12[3*indexer:4*indexer],
    simulate_ds12[4*indexer:5*indexer],simulate_ds12[5*indexer:6*indexer],simulate_ds12[6*indexer:7*indexer],simulate_ds12[7*indexer:]
])
##13
sols_13 = np.array([
    simulate_13[:indexer],simulate_13[indexer:2*indexer],simulate_13[2*indexer:3*indexer],simulate_13[3*indexer:4*indexer],
    simulate_13[4*indexer:5*indexer],simulate_13[5*indexer:6*indexer],simulate_13[6*indexer:7*indexer],simulate_13[7*indexer:]
])
sols_ds13 = np.array([
    simulate_ds13[:indexer],simulate_ds13[indexer:2*indexer],simulate_ds13[2*indexer:3*indexer],simulate_ds13[3*indexer:4*indexer],
    simulate_ds13[4*indexer:5*indexer],simulate_ds13[5*indexer:6*indexer],simulate_ds13[6*indexer:7*indexer],simulate_ds13[7*indexer:]
])
##14
sols_14 = np.array([
    simulate_14[:indexer],simulate_14[indexer:2*indexer],simulate_14[2*indexer:3*indexer],simulate_14[3*indexer:4*indexer],
    simulate_14[4*indexer:5*indexer],simulate_14[5*indexer:6*indexer],simulate_14[6*indexer:7*indexer],simulate_14[7*indexer:]
])
sols_ds14 = np.array([
    simulate_ds14[:indexer],simulate_ds14[indexer:2*indexer],simulate_ds14[2*indexer:3*indexer],simulate_ds14[3*indexer:4*indexer],
    simulate_ds14[4*indexer:5*indexer],simulate_ds14[5*indexer:6*indexer],simulate_ds14[6*indexer:7*indexer],simulate_ds14[7*indexer:]
])
##15
sols_15 = np.array([
    simulate_15[:indexer],simulate_15[indexer:2*indexer],simulate_15[2*indexer:3*indexer],simulate_15[3*indexer:4*indexer],
    simulate_15[4*indexer:5*indexer],simulate_15[5*indexer:6*indexer],simulate_15[6*indexer:7*indexer],simulate_15[7*indexer:]
])
sols_ds15 = np.array([
    simulate_ds15[:indexer],simulate_ds15[indexer:2*indexer],simulate_ds15[2*indexer:3*indexer],simulate_ds15[3*indexer:4*indexer],
    simulate_ds15[4*indexer:5*indexer],simulate_ds15[5*indexer:6*indexer],simulate_ds15[6*indexer:7*indexer],simulate_ds15[7*indexer:]
])
##16
sols_16 = np.array([
    simulate_16[:indexer],simulate_16[indexer:2*indexer],simulate_16[2*indexer:3*indexer],simulate_16[3*indexer:4*indexer],
    simulate_16[4*indexer:5*indexer],simulate_16[5*indexer:6*indexer],simulate_16[6*indexer:7*indexer],simulate_16[7*indexer:]
])
sols_ds16 = np.array([
    simulate_ds16[:indexer],simulate_ds16[indexer:2*indexer],simulate_ds16[2*indexer:3*indexer],simulate_ds16[3*indexer:4*indexer],
    simulate_ds16[4*indexer:5*indexer],simulate_ds16[5*indexer:6*indexer],simulate_ds16[6*indexer:7*indexer],simulate_ds16[7*indexer:]
])
##17
sols_17 = np.array([
    simulate_17[:indexer],simulate_17[indexer:2*indexer],simulate_17[2*indexer:3*indexer],simulate_17[3*indexer:4*indexer],
    simulate_17[4*indexer:5*indexer],simulate_17[5*indexer:6*indexer],simulate_17[6*indexer:7*indexer],simulate_17[7*indexer:]
])
sols_ds17 = np.array([
    simulate_ds17[:indexer],simulate_ds17[indexer:2*indexer],simulate_ds17[2*indexer:3*indexer],simulate_ds17[3*indexer:4*indexer],
    simulate_ds17[4*indexer:5*indexer],simulate_ds17[5*indexer:6*indexer],simulate_ds17[6*indexer:7*indexer],simulate_ds17[7*indexer:]
])
##18
sols_18 = np.array([
    simulate_18[:indexer],simulate_18[indexer:2*indexer],simulate_18[2*indexer:3*indexer],simulate_18[3*indexer:4*indexer],
    simulate_18[4*indexer:5*indexer],simulate_18[5*indexer:6*indexer],simulate_18[6*indexer:7*indexer],simulate_18[7*indexer:]
])
sols_ds18 = np.array([
    simulate_ds18[:indexer],simulate_ds18[indexer:2*indexer],simulate_ds18[2*indexer:3*indexer],simulate_ds18[3*indexer:4*indexer],
    simulate_ds18[4*indexer:5*indexer],simulate_ds18[5*indexer:6*indexer],simulate_ds18[6*indexer:7*indexer],simulate_ds18[7*indexer:]
])
##19
sols_19 = np.array([
    simulate_19[:indexer],simulate_19[indexer:2*indexer],simulate_19[2*indexer:3*indexer],simulate_19[3*indexer:4*indexer],
    simulate_19[4*indexer:5*indexer],simulate_19[5*indexer:6*indexer],simulate_19[6*indexer:7*indexer],simulate_19[7*indexer:]
])
sols_ds19 = np.array([
    simulate_ds19[:indexer],simulate_ds19[indexer:2*indexer],simulate_ds19[2*indexer:3*indexer],simulate_ds19[3*indexer:4*indexer],
    simulate_ds19[4*indexer:5*indexer],simulate_ds19[5*indexer:6*indexer],simulate_ds19[6*indexer:7*indexer],simulate_ds19[7*indexer:]
])
##20
sols_20 = np.array([
    simulate_20[:indexer],simulate_20[indexer:2*indexer],simulate_20[2*indexer:3*indexer],simulate_20[3*indexer:4*indexer],
    simulate_20[4*indexer:5*indexer],simulate_20[5*indexer:6*indexer],simulate_20[6*indexer:7*indexer],simulate_20[7*indexer:]
])
sols_ds20 = np.array([
    simulate_ds20[:indexer],simulate_ds20[indexer:2*indexer],simulate_ds20[2*indexer:3*indexer],simulate_ds20[3*indexer:4*indexer],
    simulate_ds20[4*indexer:5*indexer],simulate_ds20[5*indexer:6*indexer],simulate_ds20[6*indexer:7*indexer],simulate_ds20[7*indexer:]
])

# %%
def distance(sols_i, sols_dsi):
    return np.sqrt(
        (sols_i[0] - sols_dsi[0])**2 + (sols_i[1] - sols_dsi[1])**2 + (sols_i[2] - sols_dsi[2])**2 +
        (sols_i[3] - sols_dsi[3])**2 + (sols_i[4] - sols_dsi[4])**2 + (sols_i[5] - sols_dsi[5])**2 +
        (sols_i[6] - sols_dsi[6])**2 + (sols_i[7] - sols_dsi[7])**2
    )

# %%
dist1 = distance(sols_1, sols_ds1)
dist2 = distance(sols_2, sols_ds2)
dist3 = distance(sols_3, sols_ds3)
dist4 = distance(sols_4, sols_ds4)
dist5 = distance(sols_5, sols_ds5)
dist6 = distance(sols_6, sols_ds6)
dist7 = distance(sols_7, sols_ds7)
dist8 = distance(sols_8, sols_ds8)
dist9 = distance(sols_9, sols_ds9)
dist10 = distance(sols_10, sols_ds10)
dist11 = distance(sols_11, sols_ds11)
dist12 = distance(sols_12, sols_ds12)
dist13 = distance(sols_13, sols_ds13)
dist14 = distance(sols_14, sols_ds14)
dist15 = distance(sols_15, sols_ds15)
dist16 = distance(sols_16, sols_ds16)
dist17 = distance(sols_17, sols_ds17)
dist18 = distance(sols_18, sols_ds18)
dist19 = distance(sols_19, sols_ds19)
dist20 = distance(sols_20, sols_ds20)

distances = np.array([
    dist1,dist2,dist3,dist4,dist5,dist6,dist7,dist8,dist9,dist10,
    dist11,dist12,dist13,dist14,dist15,dist16,dist17,dist18,dist19,dist20,
])

# %%
times_ = np.linspace(0,300,3000)

plt.figure(figsize = (20,25))
for i in np.arange(1,21):
    plt.subplot(4,5,i)
    plt.plot(times_, np.log(distances[i - 1]))

plt.savefig("Plots of lyubanov exponents.jpg")
